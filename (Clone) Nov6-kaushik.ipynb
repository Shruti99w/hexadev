# %%
dbutils.fs.ls("/")

# %%
# create a df by reading the file "dbfs:/FileStore/tables/journal_dummy_dataset.csv"
df = spark.read.csv("dbfs:/FileStore/tables/journal_dummy_dataset.csv", header=True)
# display the df
display(df)
